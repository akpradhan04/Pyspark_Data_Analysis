# %% [markdown]
# ### Navigate Through Folders/ Files

# %%
dbutils.fs.ls('/Workspace/Users/email_address@gmail.com/Pyspark_Data_Analysis/datasets')

# %% [markdown]
# ### Import JSON to Notebook

# %%
df_json = spark.read.format('json').option('header',True)\
                         .option('inferSchema', True)\
                         .option('multiline', False)\
                         .load('/Workspace/Users/email_address@gmail.com/Pyspark_Data_Analysis/datasets/drivers.json')

# %% [markdown]
# ### Data Check

# %%
df_json.display()
