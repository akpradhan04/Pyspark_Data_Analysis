# %%
df = spark.read.format('csv').option('inferSchema', True)\
                        .option('header', True)\
                        .load('/Workspace/Users/email_address@gmail.com/Pyspark_Data_Analysis/datasets/BigMart Sales.csv')

# %% [markdown]
# ### Sort

# %%
from pyspark.sql.functions import *

# %% [markdown]
# Scenario 1

# %%
# df.sort('Item_Weight').display()
df.sort(col('Item_Weight').desc()).limit(10).display()

# %% [markdown]
# Scenario 2

# %%
df.sort(col('Item_Visibility').asc()).limit(10).display()

# %% [markdown]
# Scenario 3

# %%
df.sort(['Item_Weight', 'Item_Visibility'], ascending = [0, 0]).limit(10).display()

# %% [markdown]
# Scenario 4

# %%
df.sort(['Item_Weight', 'Item_Visibility'], ascending = [0, 1]).limit(10).display()

# %% [markdown]
# ### DROP

# %%
df.drop('Item_Visibility').limit(10).display()

# %%
df.drop('Item_Weight', 'Item_Fat_Content', 'Item_Type', 'Item_MRP').limit(10).display()

# %% [markdown]
# ### Drop Duplicates

# %%
df.dropDuplicates().display()

# %%
df.drop_duplicates(subset=['Item_Type']).display()

# %%
df.distinct().display()
