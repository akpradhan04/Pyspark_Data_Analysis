# %%
df = spark.read.format('csv').option('inferSchema', True)\
                        .option('header', True)\
                        .load('/Workspace/Users/email_address@gmail.com/Pyspark_Data_Analysis/datasets/BigMart Sales.csv')

# %% [markdown]
# ### String Functions

# %% [markdown]
# Init Cap

# %%
df.select(initcap('Item_Type')).limit(10).distinct().display()

# %% [markdown]
# Upper and Lower

# %%
df.select(upper('Item_Type')).limit(10).distinct().display()

# %%
df.select(lower('Item_Type').alias('Lower_Item_Type')).limit(10).distinct().display()
